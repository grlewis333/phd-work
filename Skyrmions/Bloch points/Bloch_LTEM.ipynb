# %%
import discretisedfield as df                   # Micromagnetics
import micromagneticmodel as mm                 # Micromagnetics
import oommfc as oc                             # Micromagnetics
import numpy as np                              # Maths
import ubermagtable
from matplotlib import pyplot as plt


import sys
sys.path.append('../')
import LTEM_functions as ltem

# %%
data = ubermagtable.data('bloch-point.omf')
data = np.reshape(data,(50, 50, 15, 3),order='F')
Mx,My,Mz = ltem.omf_to_mag(data)
Mx,My,Mz = Mx,My,Mz

# %%
Mxr,Myr,Mzr = ltem.rotate_magnetisation(Mx,My,Mz,ax=80,ay=0,az=0)
ltem.plot_mag(Mxr,Myr,Mzr,direction='z',s=3)

# %%
ltem.plot_phase(Mxr,Myr,Mzr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4da88596bd1d> in <module>
# ----> 1 ltem.plot_phase(Mxr,Myr,Mzr)
#
# ~\Documents\GitHub\phd-work\Skyrmions\LTEM_functions.py in plot_phase(Mx, My, Mz, ax)
#     261
#     262     # Get phase image
# --> 263     phase_B = ltem.B_phase_calc(Mx,My,Mz,x_res=3,y_res=3,z_res=2)
#     264
#     265     # Unwrap phase image
#
# NameError: name 'ltem' is not defined

# %%
np.max(Mxr)
# Out:
# 0.0

# %%
a,b,c = np.shape(Mx)

# %%
a
# Out:
# 50
